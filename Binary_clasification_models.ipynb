# %% [markdown]
# # Machine learning framework for prediction of patient-hospital readmission in US
# ### Part 2: Binary Classification Models
# #### Author: Andrea Marcela Huerfano Barbosa
# ##### Modified: 31th October

# %% [markdown]
# ### Contents
# * [I. Loading the final dataset](#I.-Loading-the-final-dataset)
# * [II. Model Performance](#II.-Model-Performance)
# * [III. Unbalanced dataset](#III.-Unbalanced-dataset)
#     * [1.Logistic Regression](#1.-Logistic-Regression)
#     * [2.Weighted Logistic Regression](#2.-Weighted-Logistic-Regression)
#     * [3. Artificial Neuronal Network](#3.-Artificial-Neuronal-Network)
#
# * [IV. Oversampling](#IV.-Oversampling )
#     * [1. Logistic Regression](#1.-Logistic-Regression)
#     * [2. KNeighbors](#2.-KNeighbors)
#     * [3. Random Forest](#3.-Random-Forest)
#     * [4. Decision Tree Classifier](#4.-Decision-Tree-Classifier)

# %% [markdown]
# ### I. Loading the final dataset

# %%
from __future__ import absolute_import, division, print_function, unicode_literals
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.linear_model import LogisticRegression
import xgboost
from xgboost import XGBClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import f_regression
from collections import Counter
from imblearn.over_sampling import SMOTE
from yellowbrick.model_selection import FeatureImportances
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input, Activation, Dropout
from tensorflow.keras.utils import plot_model
from sklearn.preprocessing import StandardScaler
from tensorflow.keras. metrics import FalseNegatives, FalsePositives, TrueNegatives
from tensorflow.keras. metrics import TruePositives, Precision, Recall
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import callbacks
import seaborn as sns
sns.set()

# %%
dataset=pd.read_csv('Clean_readmitted_oct31.csv')

# %%
dataset.head(n=3).T
# Out:
#                                   0         1          2
# Unnamed: 0                     4267      5827      67608
# encounter_id               24437208  29758806  189899286
# patient_nbr                     135       378        729
# time_in_hospital                  8         2          4
# num_lab_procedures               77        49         68
# num_procedures                    6         1          2
# num_medications                  33        11         23
# number_outpatient                 0         0          0
# number_emergency                  0         0          0
# number_inpatient                  0         0          0
# number_diagnoses                  8         3          9
# change                            1         0          0
# diabetesMed                       1         0          1
# readmitted                        1         0          0
# admission_type                    1         1          0
# Discharged_type                   0         0          1
# Admision_source                   0         0          1
# race_AfricanAmerican              0         0          0
# race_Asian                        0         0          0
# race_Caucasian                    1         1          1
# race_Hispanic                     0         0          0
# race_Other                        0         0          0
# gender_Female                     1         1          1
# gender_Male                       0         0          0
# insulin_Down                      0         0          0
# insulin_No                        0         1          1
# insulin_Steady                    1         0          0
# insulin_Up                        0         0          0
# age_Between_fourty_sixty          1         1          0
# age_Between_sixty_seventy         0         0          0
# age_Greater_seventy               0         0          1
# age_Less_fourty                   0         0          0
# A1Cresult_7                       0         0          1
# A1Cresult_8                       0         0          0
# A1Cresult_None                    1         1          0
# A1Cresult_Norm                    0         0          0
# diag_type_Circulatory             1         0          0
# diag_type_Diabetes                0         0          0
# diag_type_Digestive               0         0          0
# diag_type_Genitourinary           0         0          0
# diag_type_Injury                  0         0          1
# diag_type_Musculoskeletal         0         1          0
# diag_type_Neoplasms               0         0          0
# diag_type_Other                   0         0          0
# diag_type_Respiratory             0         0          0
# metformin_Down                    0         0          0
# metformin_No                      0         1          0
# metformin_Steady                  1         0          1
# metformin_Up                      0         0          0
# glipizide_Down                    0         0          0
# glipizide_No                      1         1          1
# glipizide_Steady                  0         0          0
# glipizide_Up                      0         0          0
# glyburide_Down                    1         0          0
# glyburide_No                      0         1          1
# glyburide_Steady                  0         0          0
# glyburide_Up                      0         0          0

# %% [markdown]
# ## II. Model Performance

# %% [markdown]
# Since the readmission correspond to a binary classification. I am going to use the following metrics to compare the performance across the models:
#
# - Confussion Matrix
# - Accuracy

# %%
def model_performance(model_prediction):
    print(classification_report(y_test, model_prediction, digits=3))

    cfm = confusion_matrix(y_test, model_prediction)

    true_negative = cfm[0][0]
    false_positive = cfm[0][1]
    false_negative = cfm[1][0]
    true_positive = cfm[1][1]

    print('Confusion Matrix: \n', cfm, '\n')

    print('True Negative:', true_negative)
    print('False Positive:', false_positive)
    print('False Negative:', false_negative)
    print('True Positive:', true_positive)
    print('Correct Predictions', 
          round((true_negative + true_positive) / len(model_prediction) * 100, 1), '%')

# %% [markdown]
# ### III. Unbalanced dataset
# #### 1. Logistic Regression

# %%
X=dataset.drop([ 'Unnamed: 0','encounter_id', 'patient_nbr', 'gender_Male','readmitted'] , axis=1)
y=dataset['readmitted']

X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.2,
                                                    stratify=y,
                                                    random_state=42)

print('Training samples: {}'.format(X_train.shape[0]))
print('Testing samples: {}'.format(X_test.shape[0]))
print('Number of features: {}'.format(X_train.shape[1]))
print('Training outcome distribution: {}'.format(np.bincount(y_train)))
print('Testing outcome distribution: {}'.format(np.bincount(y_test)))
# Out:
# Training samples: 44956
# Testing samples: 11239
# Number of features: 52
# Training outcome distribution: [41689  3267]
# Testing outcome distribution: [10422   817]

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(max_iter=1000,random_state=0)
classifier.fit(X_train, y_train)
logistic_prediction = classifier.predict(X_test)

# %%
model_performance(logistic_prediction)
# Out:
#               precision    recall  f1-score   support
#
#            0      0.928     0.999     0.962     10422
#            1      0.333     0.004     0.007       817
#
#     accuracy                          0.927     11239
#    macro avg      0.630     0.502     0.485     11239
# weighted avg      0.884     0.927     0.893     11239
#
# Confusion Matrix:
#  [[10416     6]
#  [  814     3]]
#
# True Negative: 10416
# False Positive: 6
# False Negative: 814
# True Positive: 3
# Correct Predictions 92.7 %

# %% [markdown]
# #### 2. Weighted Logistic Regression

# %%
X=dataset.drop([ 'Unnamed: 0','encounter_id', 'patient_nbr', 'gender_Male','readmitted'] , axis=1)
y=dataset['readmitted']

# %%
counts = np.bincount(y)
print("Number of positive samples in training data: {} ({:.2f}% of total)".format(
    counts[1], 100 * float(counts[1]) / len(y) ) )

weight_for_0 = 1.0 / counts[0]
weight_for_1 = 1.0 / counts[1]
# Out:
# Number of positive samples in training data: 4084 (7.27% of total)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y,
                                                    test_size=0.2,
                                                    stratify=y,
                                                    random_state=42)

# %%
classifier = LogisticRegression(max_iter=500,random_state=0,class_weight='balanced') #solver='saga', penalty='l1'
# class_weight='balanced' class_weight = {0: weight_for_0, 1: weight_for_1}
#solver  ‘liblinear’ newton-cg saga
#penalty l1-saga
#iteraciones 100, 500
classifier.fit(X_train, y_train)
weight_logistic_prediction = classifier.predict(X_test)

# %%
model_performance(weight_logistic_prediction)
# Out:
#               precision    recall  f1-score   support
#
#            0      0.954     0.662     0.782     10422
#            1      0.122     0.596     0.202       817
#
#     accuracy                          0.658     11239
#    macro avg      0.538     0.629     0.492     11239
# weighted avg      0.894     0.658     0.740     11239
#
# Confusion Matrix:
#  [[6904 3518]
#  [ 330  487]]
#
# True Negative: 6904
# False Positive: 3518
# False Negative: 330
# True Positive: 487
# Correct Predictions 65.8 %

# %% [markdown]
# #### (c) Xgboost

# %%
exgb_classifier = xgboost.XGBClassifier(max_depth=10, random_state=1)
exgb_classifier.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.300000012, max_delta_step=0, max_depth=10,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=100, n_jobs=0, num_parallel_tree=1, random_state=1,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
exgb_prediction = exgb_classifier.predict(X_test)

# %%
model_performance(exgb_prediction)
# Out:
#               precision    recall  f1-score   support
#
#            0      0.928     0.997     0.961     10422
#            1      0.190     0.010     0.019       817
#
#     accuracy                          0.925     11239
#    macro avg      0.559     0.503     0.490     11239
# weighted avg      0.874     0.925     0.893     11239
#
# Confusion Matrix:
#  [[10388    34]
#  [  809     8]]
#
# True Negative: 10388
# False Positive: 34
# False Negative: 809
# True Positive: 8
# Correct Predictions 92.5 %

# %% [markdown]
# #### 3. Artificial Neuronal Network

# %%
targets = y
targets = np.array(targets, dtype = 'uint8')
#targets.reshape((targets.shape[0],1))

features = np.array(X,dtype = 'float32' )
num_val_samples = int(len(features) * 0.2)
train_features = features[:-num_val_samples]
train_targets = targets[:-num_val_samples]
val_features = features[-num_val_samples:]
val_targets = targets[-num_val_samples:]

scaler = StandardScaler()

scaler.fit(train_features)
train_features = scaler.transform(train_features)
val_features = scaler.transform(val_features )


counts = np.bincount(train_targets)
print(
    "Number of positive samples in training data: {} ({:.2f}% of total)".format(
        counts[1], 100 * float(counts[1]) / len(train_targets)
    )
)

# Crea los pesos para el entrenamiento. Más peso a los menos frecuentes (1)
weight_for_0 = 1.0 / counts[0]
weight_for_1 = 1.0 / counts[1]

inputs = Input(shape=(train_features.shape[1],),name='capa_entrada')

# vamos construyendo capa por capa
x = Activation('relu')(inputs)
x = Dense(256, activation='relu',name='primera_capa_oculta')(x)
x = Dropout(0.3)(x)
x = Dense(256, activation='relu',name='segunda_capa_oculta')(x)
x = Dropout(0.3)(x)
x = Dense(128, activation='relu',name='tercera_capa_oculta')(x)
outputs = Dense(1, activation='sigmoid', name='capa_salida')(x)

# Creamos ahora el modelo
model = Model(inputs=inputs, outputs=outputs)

model.summary()
plot_model(model, to_file='readmission_model.png', 
           show_shapes=True)
# Out:
# Number of positive samples in training data: 3243 (7.21% of total)
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# capa_entrada (InputLayer)    [(None, 52)]              0
# _________________________________________________________________
# activation (Activation)      (None, 52)                0
# _________________________________________________________________
# primera_capa_oculta (Dense)  (None, 256)               13568
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# segunda_capa_oculta (Dense)  (None, 256)               65792
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# tercera_capa_oculta (Dense)  (None, 128)               32896
# _________________________________________________________________
# capa_salida (Dense)          (None, 1)                 129
# =================================================================
# Total params: 112,385
# Trainable params: 112,385
# Non-trainable params: 0
# _________________________________________________________________

# %%
metrics = [
    FalseNegatives(name="fn"),
    FalsePositives(name="fp"),
    TrueNegatives(name="tn"),
    TruePositives(name="tp"),
    Precision(name="precision"),
    Recall(name="recall"),
]

model.compile(optimizer=Adam(0.0001), loss="binary_crossentropy", metrics=metrics)

# %%
callbacks = [callbacks.ModelCheckpoint("readmission_model_at_epoch_{epoch}.h5")]
class_weight = {0: weight_for_0, 1: weight_for_1}

history = model.fit(
    train_features,
    train_targets,
    batch_size=2048,
    epochs=100,
    verbose=2,
    callbacks=callbacks,
    validation_data=(val_features, val_targets),
    class_weight=class_weight,
) ###El recall muestra la eficacia sobre lastransacciones fraudulentas
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 44956 samples, validate on 11239 samples
# Epoch 1/100
# 44956/44956 - 5s - loss: 3.1885e-05 - fn: 2499.0000 - fp: 9166.0000 - tn: 32547.0000 - tp: 744.0000 - precision: 0.0751 - recall: 0.2294 - val_loss: 3.1578e-05 - val_fn: 561.0000 - val_fp: 2940.0000 - val_tn: 7458.0000 - val_tp: 280.0000 - val_precision: 0.0870 - val_recall: 0.3329
# Epoch 2/100
# 44956/44956 - 2s - loss: 3.1248e-05 - fn: 1931.0000 - fp: 15054.0000 - tn: 26659.0000 - tp: 1312.0000 - precision: 0.0802 - recall: 0.4046 - val_loss: 3.1286e-05 - val_fn: 357.0000 - val_fp: 5544.0000 - val_tn: 4854.0000 - val_tp: 484.0000 - val_precision: 0.0803 - val_recall: 0.5755
# Epoch 3/100
# 44956/44956 - 2s - loss: 3.1150e-05 - fn: 1530.0000 - fp: 20409.0000 - tn: 21304.0000 - tp: 1713.0000 - precision: 0.0774 - recall: 0.5282 - val_loss: 3.1182e-05 - val_fn: 228.0000 - val_fp: 6920.0000 - val_tn: 3478.0000 - val_tp: 613.0000 - val_precision: 0.0814 - val_recall: 0.7289
# Epoch 4/100
# 44956/44956 - 2s - loss: 3.1093e-05 - fn: 1302.0000 - fp: 23046.0000 - tn: 18667.0000 - tp: 1941.0000 - precision: 0.0777 - recall: 0.5985 - val_loss: 3.1118e-05 - val_fn: 178.0000 - val_fp: 7471.0000 - val_tn: 2927.0000 - val_tp: 663.0000 - val_precision: 0.0815 - val_recall: 0.7883
# Epoch 5/100
# 44956/44956 - 2s - loss: 3.0792e-05 - fn: 1192.0000 - fp: 23152.0000 - tn: 18561.0000 - tp: 2051.0000 - precision: 0.0814 - recall: 0.6324 - val_loss: 3.1023e-05 - val_fn: 210.0000 - val_fp: 6920.0000 - val_tn: 3478.0000 - val_tp: 631.0000 - val_precision: 0.0836 - val_recall: 0.7503
# Epoch 6/100
# 44956/44956 - 2s - loss: 3.0889e-05 - fn: 1317.0000 - fp: 21893.0000 - tn: 19820.0000 - tp: 1926.0000 - precision: 0.0809 - recall: 0.5939 - val_loss: 3.0940e-05 - val_fn: 232.0000 - val_fp: 6603.0000 - val_tn: 3795.0000 - val_tp: 609.0000 - val_precision: 0.0844 - val_recall: 0.7241
# Epoch 7/100
# 44956/44956 - 2s - loss: 3.0832e-05 - fn: 1348.0000 - fp: 21396.0000 - tn: 20317.0000 - tp: 1895.0000 - precision: 0.0814 - recall: 0.5843 - val_loss: 3.0868e-05 - val_fn: 245.0000 - val_fp: 6384.0000 - val_tn: 4014.0000 - val_tp: 596.0000 - val_precision: 0.0854 - val_recall: 0.7087
# Epoch 8/100
# 44956/44956 - 2s - loss: 3.0724e-05 - fn: 1281.0000 - fp: 21863.0000 - tn: 19850.0000 - tp: 1962.0000 - precision: 0.0824 - recall: 0.6050 - val_loss: 3.0802e-05 - val_fn: 223.0000 - val_fp: 6480.0000 - val_tn: 3918.0000 - val_tp: 618.0000 - val_precision: 0.0871 - val_recall: 0.7348
# Epoch 9/100
# 44956/44956 - 2s - loss: 3.0673e-05 - fn: 1284.0000 - fp: 21302.0000 - tn: 20411.0000 - tp: 1959.0000 - precision: 0.0842 - recall: 0.6041 - val_loss: 3.0728e-05 - val_fn: 244.0000 - val_fp: 6123.0000 - val_tn: 4275.0000 - val_tp: 597.0000 - val_precision: 0.0888 - val_recall: 0.7099
# Epoch 10/100
# 44956/44956 - 2s - loss: 3.0498e-05 - fn: 1268.0000 - fp: 21041.0000 - tn: 20672.0000 - tp: 1975.0000 - precision: 0.0858 - recall: 0.6090 - val_loss: 3.0664e-05 - val_fn: 262.0000 - val_fp: 5862.0000 - val_tn: 4536.0000 - val_tp: 579.0000 - val_precision: 0.0899 - val_recall: 0.6885
# Epoch 11/100
# 44956/44956 - 2s - loss: 3.0484e-05 - fn: 1345.0000 - fp: 20055.0000 - tn: 21658.0000 - tp: 1898.0000 - precision: 0.0865 - recall: 0.5853 - val_loss: 3.0603e-05 - val_fn: 278.0000 - val_fp: 5507.0000 - val_tn: 4891.0000 - val_tp: 563.0000 - val_precision: 0.0928 - val_recall: 0.6694
# Epoch 12/100
# 44956/44956 - 2s - loss: 3.0376e-05 - fn: 1305.0000 - fp: 19742.0000 - tn: 21971.0000 - tp: 1938.0000 - precision: 0.0894 - recall: 0.5976 - val_loss: 3.0551e-05 - val_fn: 285.0000 - val_fp: 5384.0000 - val_tn: 5014.0000 - val_tp: 556.0000 - val_precision: 0.0936 - val_recall: 0.6611
# Epoch 13/100
# 44956/44956 - 2s - loss: 3.0354e-05 - fn: 1378.0000 - fp: 19244.0000 - tn: 22469.0000 - tp: 1865.0000 - precision: 0.0884 - recall: 0.5751 - val_loss: 3.0503e-05 - val_fn: 298.0000 - val_fp: 5189.0000 - val_tn: 5209.0000 - val_tp: 543.0000 - val_precision: 0.0947 - val_recall: 0.6457
# Epoch 14/100
# 44956/44956 - 3s - loss: 3.0284e-05 - fn: 1376.0000 - fp: 18469.0000 - tn: 23244.0000 - tp: 1867.0000 - precision: 0.0918 - recall: 0.5757 - val_loss: 3.0456e-05 - val_fn: 302.0000 - val_fp: 5099.0000 - val_tn: 5299.0000 - val_tp: 539.0000 - val_precision: 0.0956 - val_recall: 0.6409
# Epoch 15/100
# 44956/44956 - 2s - loss: 3.0195e-05 - fn: 1331.0000 - fp: 18441.0000 - tn: 23272.0000 - tp: 1912.0000 - precision: 0.0939 - recall: 0.5896 - val_loss: 3.0417e-05 - val_fn: 315.0000 - val_fp: 4998.0000 - val_tn: 5400.0000 - val_tp: 526.0000 - val_precision: 0.0952 - val_recall: 0.6254
# Epoch 16/100
# 44956/44956 - 2s - loss: 3.0122e-05 - fn: 1353.0000 - fp: 18238.0000 - tn: 23475.0000 - tp: 1890.0000 - precision: 0.0939 - recall: 0.5828 - val_loss: 3.0374e-05 - val_fn: 330.0000 - val_fp: 4814.0000 - val_tn: 5584.0000 - val_tp: 511.0000 - val_precision: 0.0960 - val_recall: 0.6076
# Epoch 17/100
# 44956/44956 - 2s - loss: 3.0149e-05 - fn: 1359.0000 - fp: 17755.0000 - tn: 23958.0000 - tp: 1884.0000 - precision: 0.0959 - recall: 0.5809 - val_loss: 3.0340e-05 - val_fn: 326.0000 - val_fp: 4784.0000 - val_tn: 5614.0000 - val_tp: 515.0000 - val_precision: 0.0972 - val_recall: 0.6124
# Epoch 18/100
# 44956/44956 - 2s - loss: 3.0072e-05 - fn: 1380.0000 - fp: 17479.0000 - tn: 24234.0000 - tp: 1863.0000 - precision: 0.0963 - recall: 0.5745 - val_loss: 3.0303e-05 - val_fn: 334.0000 - val_fp: 4619.0000 - val_tn: 5779.0000 - val_tp: 507.0000 - val_precision: 0.0989 - val_recall: 0.6029
# Epoch 19/100
# 44956/44956 - 2s - loss: 2.9948e-05 - fn: 1320.0000 - fp: 17446.0000 - tn: 24267.0000 - tp: 1923.0000 - precision: 0.0993 - recall: 0.5930 - val_loss: 3.0275e-05 - val_fn: 341.0000 - val_fp: 4491.0000 - val_tn: 5907.0000 - val_tp: 500.0000 - val_precision: 0.1002 - val_recall: 0.5945
# Epoch 20/100
# 44956/44956 - 2s - loss: 3.0000e-05 - fn: 1430.0000 - fp: 16743.0000 - tn: 24970.0000 - tp: 1813.0000 - precision: 0.0977 - recall: 0.5591 - val_loss: 3.0249e-05 - val_fn: 350.0000 - val_fp: 4377.0000 - val_tn: 6021.0000 - val_tp: 491.0000 - val_precision: 0.1009 - val_recall: 0.5838
# Epoch 21/100
# 44956/44956 - 2s - loss: 3.0024e-05 - fn: 1431.0000 - fp: 16472.0000 - tn: 25241.0000 - tp: 1812.0000 - precision: 0.0991 - recall: 0.5587 - val_loss: 3.0226e-05 - val_fn: 349.0000 - val_fp: 4344.0000 - val_tn: 6054.0000 - val_tp: 492.0000 - val_precision: 0.1017 - val_recall: 0.5850
# Epoch 22/100
# 44956/44956 - 2s - loss: 2.9931e-05 - fn: 1336.0000 - fp: 17392.0000 - tn: 24321.0000 - tp: 1907.0000 - precision: 0.0988 - recall: 0.5880 - val_loss: 3.0206e-05 - val_fn: 337.0000 - val_fp: 4479.0000 - val_tn: 5919.0000 - val_tp: 504.0000 - val_precision: 0.1011 - val_recall: 0.5993
# Epoch 23/100
# 44956/44956 - 3s - loss: 2.9869e-05 - fn: 1394.0000 - fp: 16836.0000 - tn: 24877.0000 - tp: 1849.0000 - precision: 0.0990 - recall: 0.5702 - val_loss: 3.0184e-05 - val_fn: 351.0000 - val_fp: 4313.0000 - val_tn: 6085.0000 - val_tp: 490.0000 - val_precision: 0.1020 - val_recall: 0.5826
# Epoch 24/100
# 44956/44956 - 2s - loss: 2.9754e-05 - fn: 1392.0000 - fp: 16127.0000 - tn: 25586.0000 - tp: 1851.0000 - precision: 0.1030 - recall: 0.5708 - val_loss: 3.0164e-05 - val_fn: 361.0000 - val_fp: 4155.0000 - val_tn: 6243.0000 - val_tp: 480.0000 - val_precision: 0.1036 - val_recall: 0.5707
# Epoch 25/100
# 44956/44956 - 2s - loss: 2.9792e-05 - fn: 1395.0000 - fp: 16186.0000 - tn: 25527.0000 - tp: 1848.0000 - precision: 0.1025 - recall: 0.5698 - val_loss: 3.0147e-05 - val_fn: 354.0000 - val_fp: 4251.0000 - val_tn: 6147.0000 - val_tp: 487.0000 - val_precision: 0.1028 - val_recall: 0.5791
# Epoch 26/100
# 44956/44956 - 3s - loss: 2.9885e-05 - fn: 1402.0000 - fp: 16393.0000 - tn: 25320.0000 - tp: 1841.0000 - precision: 0.1010 - recall: 0.5677 - val_loss: 3.0137e-05 - val_fn: 350.0000 - val_fp: 4229.0000 - val_tn: 6169.0000 - val_tp: 491.0000 - val_precision: 0.1040 - val_recall: 0.5838
# Epoch 27/100
# 44956/44956 - 2s - loss: 2.9697e-05 - fn: 1336.0000 - fp: 16379.0000 - tn: 25334.0000 - tp: 1907.0000 - precision: 0.1043 - recall: 0.5880 - val_loss: 3.0125e-05 - val_fn: 349.0000 - val_fp: 4231.0000 - val_tn: 6167.0000 - val_tp: 492.0000 - val_precision: 0.1042 - val_recall: 0.5850
# Epoch 28/100
# 44956/44956 - 2s - loss: 2.9770e-05 - fn: 1382.0000 - fp: 16116.0000 - tn: 25597.0000 - tp: 1861.0000 - precision: 0.1035 - recall: 0.5739 - val_loss: 3.0112e-05 - val_fn: 352.0000 - val_fp: 4148.0000 - val_tn: 6250.0000 - val_tp: 489.0000 - val_precision: 0.1055 - val_recall: 0.5815
# Epoch 29/100
# 44956/44956 - 2s - loss: 2.9699e-05 - fn: 1406.0000 - fp: 15798.0000 - tn: 25915.0000 - tp: 1837.0000 - precision: 0.1042 - recall: 0.5665 - val_loss: 3.0100e-05 - val_fn: 355.0000 - val_fp: 4064.0000 - val_tn: 6334.0000 - val_tp: 486.0000 - val_precision: 0.1068 - val_recall: 0.5779
# Epoch 30/100
# 44956/44956 - 2s - loss: 2.9745e-05 - fn: 1407.0000 - fp: 15848.0000 - tn: 25865.0000 - tp: 1836.0000 - precision: 0.1038 - recall: 0.5661 - val_loss: 3.0092e-05 - val_fn: 351.0000 - val_fp: 4133.0000 - val_tn: 6265.0000 - val_tp: 490.0000 - val_precision: 0.1060 - val_recall: 0.5826
# Epoch 31/100
# 44956/44956 - 2s - loss: 2.9697e-05 - fn: 1351.0000 - fp: 15869.0000 - tn: 25844.0000 - tp: 1892.0000 - precision: 0.1065 - recall: 0.5834 - val_loss: 3.0084e-05 - val_fn: 348.0000 - val_fp: 4149.0000 - val_tn: 6249.0000 - val_tp: 493.0000 - val_precision: 0.1062 - val_recall: 0.5862
# Epoch 32/100
# 44956/44956 - 2s - loss: 2.9632e-05 - fn: 1390.0000 - fp: 15831.0000 - tn: 25882.0000 - tp: 1853.0000 - precision: 0.1048 - recall: 0.5714 - val_loss: 3.0077e-05 - val_fn: 352.0000 - val_fp: 4120.0000 - val_tn: 6278.0000 - val_tp: 489.0000 - val_precision: 0.1061 - val_recall: 0.5815
# Epoch 33/100
# 44956/44956 - 2s - loss: 2.9577e-05 - fn: 1357.0000 - fp: 15562.0000 - tn: 26151.0000 - tp: 1886.0000 - precision: 0.1081 - recall: 0.5816 - val_loss: 3.0068e-05 - val_fn: 353.0000 - val_fp: 4076.0000 - val_tn: 6322.0000 - val_tp: 488.0000 - val_precision: 0.1069 - val_recall: 0.5803
# Epoch 34/100
# 44956/44956 - 2s - loss: 2.9536e-05 - fn: 1382.0000 - fp: 15707.0000 - tn: 26006.0000 - tp: 1861.0000 - precision: 0.1059 - recall: 0.5739 - val_loss: 3.0057e-05 - val_fn: 355.0000 - val_fp: 4024.0000 - val_tn: 6374.0000 - val_tp: 486.0000 - val_precision: 0.1078 - val_recall: 0.5779
# Epoch 35/100
# 44956/44956 - 2s - loss: 2.9531e-05 - fn: 1340.0000 - fp: 15358.0000 - tn: 26355.0000 - tp: 1903.0000 - precision: 0.1102 - recall: 0.5868 - val_loss: 3.0049e-05 - val_fn: 367.0000 - val_fp: 3916.0000 - val_tn: 6482.0000 - val_tp: 474.0000 - val_precision: 0.1080 - val_recall: 0.5636
# Epoch 36/100
# 44956/44956 - 2s - loss: 2.9584e-05 - fn: 1419.0000 - fp: 15127.0000 - tn: 26586.0000 - tp: 1824.0000 - precision: 0.1076 - recall: 0.5624 - val_loss: 3.0042e-05 - val_fn: 360.0000 - val_fp: 3992.0000 - val_tn: 6406.0000 - val_tp: 481.0000 - val_precision: 0.1075 - val_recall: 0.5719
# Epoch 37/100
# 44956/44956 - 2s - loss: 2.9583e-05 - fn: 1375.0000 - fp: 15892.0000 - tn: 25821.0000 - tp: 1868.0000 - precision: 0.1052 - recall: 0.5760 - val_loss: 3.0034e-05 - val_fn: 355.0000 - val_fp: 4041.0000 - val_tn: 6357.0000 - val_tp: 486.0000 - val_precision: 0.1074 - val_recall: 0.5779
# Epoch 38/100
# 44956/44956 - 2s - loss: 2.9582e-05 - fn: 1380.0000 - fp: 15513.0000 - tn: 26200.0000 - tp: 1863.0000 - precision: 0.1072 - recall: 0.5745 - val_loss: 3.0030e-05 - val_fn: 360.0000 - val_fp: 3960.0000 - val_tn: 6438.0000 - val_tp: 481.0000 - val_precision: 0.1083 - val_recall: 0.5719
# Epoch 39/100
# 44956/44956 - 2s - loss: 2.9572e-05 - fn: 1361.0000 - fp: 15639.0000 - tn: 26074.0000 - tp: 1882.0000 - precision: 0.1074 - recall: 0.5803 - val_loss: 3.0025e-05 - val_fn: 358.0000 - val_fp: 3985.0000 - val_tn: 6413.0000 - val_tp: 483.0000 - val_precision: 0.1081 - val_recall: 0.5743
# Epoch 40/100
# 44956/44956 - 2s - loss: 2.9574e-05 - fn: 1407.0000 - fp: 15193.0000 - tn: 26520.0000 - tp: 1836.0000 - precision: 0.1078 - recall: 0.5661 - val_loss: 3.0019e-05 - val_fn: 356.0000 - val_fp: 3980.0000 - val_tn: 6418.0000 - val_tp: 485.0000 - val_precision: 0.1086 - val_recall: 0.5767
# Epoch 41/100
# 44956/44956 - 2s - loss: 2.9551e-05 - fn: 1413.0000 - fp: 14971.0000 - tn: 26742.0000 - tp: 1830.0000 - precision: 0.1089 - recall: 0.5643 - val_loss: 3.0013e-05 - val_fn: 362.0000 - val_fp: 3866.0000 - val_tn: 6532.0000 - val_tp: 479.0000 - val_precision: 0.1102 - val_recall: 0.5696
# Epoch 42/100
# 44956/44956 - 2s - loss: 2.9497e-05 - fn: 1388.0000 - fp: 15366.0000 - tn: 26347.0000 - tp: 1855.0000 - precision: 0.1077 - recall: 0.5720 - val_loss: 3.0008e-05 - val_fn: 352.0000 - val_fp: 3992.0000 - val_tn: 6406.0000 - val_tp: 489.0000 - val_precision: 0.1091 - val_recall: 0.5815
# Epoch 43/100
# 44956/44956 - 2s - loss: 2.9515e-05 - fn: 1386.0000 - fp: 15322.0000 - tn: 26391.0000 - tp: 1857.0000 - precision: 0.1081 - recall: 0.5726 - val_loss: 3.0003e-05 - val_fn: 353.0000 - val_fp: 3965.0000 - val_tn: 6433.0000 - val_tp: 488.0000 - val_precision: 0.1096 - val_recall: 0.5803
# Epoch 44/100
# 44956/44956 - 2s - loss: 2.9459e-05 - fn: 1388.0000 - fp: 15181.0000 - tn: 26532.0000 - tp: 1855.0000 - precision: 0.1089 - recall: 0.5720 - val_loss: 2.9999e-05 - val_fn: 358.0000 - val_fp: 3914.0000 - val_tn: 6484.0000 - val_tp: 483.0000 - val_precision: 0.1098 - val_recall: 0.5743
# Epoch 45/100
# 44956/44956 - 2s - loss: 2.9509e-05 - fn: 1368.0000 - fp: 15245.0000 - tn: 26468.0000 - tp: 1875.0000 - precision: 0.1095 - recall: 0.5782 - val_loss: 2.9997e-05 - val_fn: 350.0000 - val_fp: 3988.0000 - val_tn: 6410.0000 - val_tp: 491.0000 - val_precision: 0.1096 - val_recall: 0.5838
# Epoch 46/100
# 44956/44956 - 2s - loss: 2.9429e-05 - fn: 1360.0000 - fp: 15376.0000 - tn: 26337.0000 - tp: 1883.0000 - precision: 0.1091 - recall: 0.5806 - val_loss: 2.9994e-05 - val_fn: 360.0000 - val_fp: 3885.0000 - val_tn: 6513.0000 - val_tp: 481.0000 - val_precision: 0.1102 - val_recall: 0.5719
# Epoch 47/100
# 44956/44956 - 2s - loss: 2.9376e-05 - fn: 1380.0000 - fp: 15085.0000 - tn: 26628.0000 - tp: 1863.0000 - precision: 0.1099 - recall: 0.5745 - val_loss: 2.9988e-05 - val_fn: 350.0000 - val_fp: 3978.0000 - val_tn: 6420.0000 - val_tp: 491.0000 - val_precision: 0.1099 - val_recall: 0.5838
# Epoch 48/100
# 44956/44956 - 2s - loss: 2.9487e-05 - fn: 1407.0000 - fp: 14919.0000 - tn: 26794.0000 - tp: 1836.0000 - precision: 0.1096 - recall: 0.5661 - val_loss: 2.9986e-05 - val_fn: 364.0000 - val_fp: 3872.0000 - val_tn: 6526.0000 - val_tp: 477.0000 - val_precision: 0.1097 - val_recall: 0.5672
# Epoch 49/100
# 44956/44956 - 2s - loss: 2.9449e-05 - fn: 1365.0000 - fp: 15071.0000 - tn: 26642.0000 - tp: 1878.0000 - precision: 0.1108 - recall: 0.5791 - val_loss: 2.9984e-05 - val_fn: 351.0000 - val_fp: 3989.0000 - val_tn: 6409.0000 - val_tp: 490.0000 - val_precision: 0.1094 - val_recall: 0.5826
# Epoch 50/100
# 44956/44956 - 2s - loss: 2.9354e-05 - fn: 1374.0000 - fp: 15175.0000 - tn: 26538.0000 - tp: 1869.0000 - precision: 0.1097 - recall: 0.5763 - val_loss: 2.9980e-05 - val_fn: 353.0000 - val_fp: 3955.0000 - val_tn: 6443.0000 - val_tp: 488.0000 - val_precision: 0.1098 - val_recall: 0.5803
# Epoch 51/100
# 44956/44956 - 2s - loss: 2.9291e-05 - fn: 1337.0000 - fp: 15248.0000 - tn: 26465.0000 - tp: 1906.0000 - precision: 0.1111 - recall: 0.5877 - val_loss: 2.9975e-05 - val_fn: 353.0000 - val_fp: 3910.0000 - val_tn: 6488.0000 - val_tp: 488.0000 - val_precision: 0.1110 - val_recall: 0.5803
# Epoch 52/100
# 44956/44956 - 2s - loss: 2.9397e-05 - fn: 1410.0000 - fp: 14682.0000 - tn: 27031.0000 - tp: 1833.0000 - precision: 0.1110 - recall: 0.5652 - val_loss: 2.9972e-05 - val_fn: 353.0000 - val_fp: 3900.0000 - val_tn: 6498.0000 - val_tp: 488.0000 - val_precision: 0.1112 - val_recall: 0.5803
# Epoch 53/100
# 44956/44956 - 2s - loss: 2.9308e-05 - fn: 1368.0000 - fp: 14991.0000 - tn: 26722.0000 - tp: 1875.0000 - precision: 0.1112 - recall: 0.5782 - val_loss: 2.9967e-05 - val_fn: 351.0000 - val_fp: 3947.0000 - val_tn: 6451.0000 - val_tp: 490.0000 - val_precision: 0.1104 - val_recall: 0.5826
# Epoch 54/100
# 44956/44956 - 2s - loss: 2.9351e-05 - fn: 1408.0000 - fp: 14783.0000 - tn: 26930.0000 - tp: 1835.0000 - precision: 0.1104 - recall: 0.5658 - val_loss: 2.9965e-05 - val_fn: 355.0000 - val_fp: 3896.0000 - val_tn: 6502.0000 - val_tp: 486.0000 - val_precision: 0.1109 - val_recall: 0.5779
# Epoch 55/100
# 44956/44956 - 2s - loss: 2.9245e-05 - fn: 1331.0000 - fp: 15086.0000 - tn: 26627.0000 - tp: 1912.0000 - precision: 0.1125 - recall: 0.5896 - val_loss: 2.9961e-05 - val_fn: 350.0000 - val_fp: 3993.0000 - val_tn: 6405.0000 - val_tp: 491.0000 - val_precision: 0.1095 - val_recall: 0.5838
# Epoch 56/100
# 44956/44956 - 2s - loss: 2.9275e-05 - fn: 1350.0000 - fp: 14909.0000 - tn: 26804.0000 - tp: 1893.0000 - precision: 0.1127 - recall: 0.5837 - val_loss: 2.9957e-05 - val_fn: 356.0000 - val_fp: 3909.0000 - val_tn: 6489.0000 - val_tp: 485.0000 - val_precision: 0.1104 - val_recall: 0.5767
# Epoch 57/100
# 44956/44956 - 2s - loss: 2.9348e-05 - fn: 1373.0000 - fp: 15072.0000 - tn: 26641.0000 - tp: 1870.0000 - precision: 0.1104 - recall: 0.5766 - val_loss: 2.9954e-05 - val_fn: 356.0000 - val_fp: 3912.0000 - val_tn: 6486.0000 - val_tp: 485.0000 - val_precision: 0.1103 - val_recall: 0.5767
# Epoch 58/100
# 44956/44956 - 2s - loss: 2.9223e-05 - fn: 1371.0000 - fp: 14477.0000 - tn: 27236.0000 - tp: 1872.0000 - precision: 0.1145 - recall: 0.5772 - val_loss: 2.9950e-05 - val_fn: 356.0000 - val_fp: 3897.0000 - val_tn: 6501.0000 - val_tp: 485.0000 - val_precision: 0.1107 - val_recall: 0.5767
# Epoch 59/100
# 44956/44956 - 2s - loss: 2.9262e-05 - fn: 1319.0000 - fp: 15263.0000 - tn: 26450.0000 - tp: 1924.0000 - precision: 0.1119 - recall: 0.5933 - val_loss: 2.9948e-05 - val_fn: 342.0000 - val_fp: 4037.0000 - val_tn: 6361.0000 - val_tp: 499.0000 - val_precision: 0.1100 - val_recall: 0.5933
# Epoch 60/100
# 44956/44956 - 2s - loss: 2.9238e-05 - fn: 1371.0000 - fp: 14865.0000 - tn: 26848.0000 - tp: 1872.0000 - precision: 0.1118 - recall: 0.5772 - val_loss: 2.9948e-05 - val_fn: 357.0000 - val_fp: 3878.0000 - val_tn: 6520.0000 - val_tp: 484.0000 - val_precision: 0.1110 - val_recall: 0.5755
# Epoch 61/100
# 44956/44956 - 2s - loss: 2.9330e-05 - fn: 1395.0000 - fp: 14752.0000 - tn: 26961.0000 - tp: 1848.0000 - precision: 0.1113 - recall: 0.5698 - val_loss: 2.9942e-05 - val_fn: 350.0000 - val_fp: 3952.0000 - val_tn: 6446.0000 - val_tp: 491.0000 - val_precision: 0.1105 - val_recall: 0.5838
# Epoch 62/100
# 44956/44956 - 2s - loss: 2.9203e-05 - fn: 1370.0000 - fp: 14840.0000 - tn: 26873.0000 - tp: 1873.0000 - precision: 0.1121 - recall: 0.5776 - val_loss: 2.9940e-05 - val_fn: 346.0000 - val_fp: 3991.0000 - val_tn: 6407.0000 - val_tp: 495.0000 - val_precision: 0.1103 - val_recall: 0.5886
# Epoch 63/100
# 44956/44956 - 2s - loss: 2.9239e-05 - fn: 1333.0000 - fp: 15115.0000 - tn: 26598.0000 - tp: 1910.0000 - precision: 0.1122 - recall: 0.5890 - val_loss: 2.9945e-05 - val_fn: 346.0000 - val_fp: 3978.0000 - val_tn: 6420.0000 - val_tp: 495.0000 - val_precision: 0.1107 - val_recall: 0.5886
# Epoch 64/100
# 44956/44956 - 2s - loss: 2.9233e-05 - fn: 1352.0000 - fp: 15066.0000 - tn: 26647.0000 - tp: 1891.0000 - precision: 0.1115 - recall: 0.5831 - val_loss: 2.9942e-05 - val_fn: 347.0000 - val_fp: 3967.0000 - val_tn: 6431.0000 - val_tp: 494.0000 - val_precision: 0.1107 - val_recall: 0.5874
# Epoch 65/100
# 44956/44956 - 2s - loss: 2.9167e-05 - fn: 1356.0000 - fp: 14585.0000 - tn: 27128.0000 - tp: 1887.0000 - precision: 0.1146 - recall: 0.5819 - val_loss: 2.9943e-05 - val_fn: 359.0000 - val_fp: 3856.0000 - val_tn: 6542.0000 - val_tp: 482.0000 - val_precision: 0.1111 - val_recall: 0.5731
# Epoch 66/100
# 44956/44956 - 2s - loss: 2.9238e-05 - fn: 1301.0000 - fp: 15122.0000 - tn: 26591.0000 - tp: 1942.0000 - precision: 0.1138 - recall: 0.5988 - val_loss: 2.9941e-05 - val_fn: 342.0000 - val_fp: 4010.0000 - val_tn: 6388.0000 - val_tp: 499.0000 - val_precision: 0.1107 - val_recall: 0.5933
# Epoch 67/100
# 44956/44956 - 2s - loss: 2.9212e-05 - fn: 1337.0000 - fp: 15112.0000 - tn: 26601.0000 - tp: 1906.0000 - precision: 0.1120 - recall: 0.5877 - val_loss: 2.9938e-05 - val_fn: 348.0000 - val_fp: 3928.0000 - val_tn: 6470.0000 - val_tp: 493.0000 - val_precision: 0.1115 - val_recall: 0.5862
# Epoch 68/100
# 44956/44956 - 2s - loss: 2.9277e-05 - fn: 1393.0000 - fp: 14751.0000 - tn: 26962.0000 - tp: 1850.0000 - precision: 0.1114 - recall: 0.5705 - val_loss: 2.9935e-05 - val_fn: 344.0000 - val_fp: 3980.0000 - val_tn: 6418.0000 - val_tp: 497.0000 - val_precision: 0.1110 - val_recall: 0.5910
# Epoch 69/100
# 44956/44956 - 2s - loss: 2.9200e-05 - fn: 1321.0000 - fp: 15016.0000 - tn: 26697.0000 - tp: 1922.0000 - precision: 0.1135 - recall: 0.5927 - val_loss: 2.9930e-05 - val_fn: 348.0000 - val_fp: 3964.0000 - val_tn: 6434.0000 - val_tp: 493.0000 - val_precision: 0.1106 - val_recall: 0.5862
# Epoch 70/100
# 44956/44956 - 2s - loss: 2.9284e-05 - fn: 1355.0000 - fp: 14875.0000 - tn: 26838.0000 - tp: 1888.0000 - precision: 0.1126 - recall: 0.5822 - val_loss: 2.9929e-05 - val_fn: 343.0000 - val_fp: 4052.0000 - val_tn: 6346.0000 - val_tp: 498.0000 - val_precision: 0.1095 - val_recall: 0.5922
# Epoch 71/100
# 44956/44956 - 2s - loss: 2.9172e-05 - fn: 1349.0000 - fp: 14673.0000 - tn: 27040.0000 - tp: 1894.0000 - precision: 0.1143 - recall: 0.5840 - val_loss: 2.9929e-05 - val_fn: 348.0000 - val_fp: 3966.0000 - val_tn: 6432.0000 - val_tp: 493.0000 - val_precision: 0.1106 - val_recall: 0.5862
# Epoch 72/100
# 44956/44956 - 2s - loss: 2.9211e-05 - fn: 1308.0000 - fp: 15206.0000 - tn: 26507.0000 - tp: 1935.0000 - precision: 0.1129 - recall: 0.5967 - val_loss: 2.9928e-05 - val_fn: 337.0000 - val_fp: 4103.0000 - val_tn: 6295.0000 - val_tp: 504.0000 - val_precision: 0.1094 - val_recall: 0.5993
# Epoch 73/100
# 44956/44956 - 2s - loss: 2.9281e-05 - fn: 1355.0000 - fp: 14928.0000 - tn: 26785.0000 - tp: 1888.0000 - precision: 0.1123 - recall: 0.5822 - val_loss: 2.9924e-05 - val_fn: 347.0000 - val_fp: 3971.0000 - val_tn: 6427.0000 - val_tp: 494.0000 - val_precision: 0.1106 - val_recall: 0.5874
# Epoch 74/100
# 44956/44956 - 2s - loss: 2.9146e-05 - fn: 1341.0000 - fp: 14884.0000 - tn: 26829.0000 - tp: 1902.0000 - precision: 0.1133 - recall: 0.5865 - val_loss: 2.9919e-05 - val_fn: 347.0000 - val_fp: 3981.0000 - val_tn: 6417.0000 - val_tp: 494.0000 - val_precision: 0.1104 - val_recall: 0.5874
# Epoch 75/100
# 44956/44956 - 2s - loss: 2.9234e-05 - fn: 1353.0000 - fp: 14826.0000 - tn: 26887.0000 - tp: 1890.0000 - precision: 0.1131 - recall: 0.5828 - val_loss: 2.9918e-05 - val_fn: 345.0000 - val_fp: 3996.0000 - val_tn: 6402.0000 - val_tp: 496.0000 - val_precision: 0.1104 - val_recall: 0.5898
# Epoch 76/100
# 44956/44956 - 2s - loss: 2.9165e-05 - fn: 1335.0000 - fp: 14984.0000 - tn: 26729.0000 - tp: 1908.0000 - precision: 0.1130 - recall: 0.5883 - val_loss: 2.9915e-05 - val_fn: 340.0000 - val_fp: 4077.0000 - val_tn: 6321.0000 - val_tp: 501.0000 - val_precision: 0.1094 - val_recall: 0.5957
# Epoch 77/100
# 44956/44956 - 2s - loss: 2.9255e-05 - fn: 1333.0000 - fp: 15314.0000 - tn: 26399.0000 - tp: 1910.0000 - precision: 0.1109 - recall: 0.5890 - val_loss: 2.9916e-05 - val_fn: 334.0000 - val_fp: 4122.0000 - val_tn: 6276.0000 - val_tp: 507.0000 - val_precision: 0.1095 - val_recall: 0.6029
# Epoch 78/100
# 44956/44956 - 2s - loss: 2.9148e-05 - fn: 1365.0000 - fp: 15140.0000 - tn: 26573.0000 - tp: 1878.0000 - precision: 0.1104 - recall: 0.5791 - val_loss: 2.9914e-05 - val_fn: 343.0000 - val_fp: 4008.0000 - val_tn: 6390.0000 - val_tp: 498.0000 - val_precision: 0.1105 - val_recall: 0.5922
# Epoch 79/100
# 44956/44956 - 2s - loss: 2.9060e-05 - fn: 1310.0000 - fp: 15004.0000 - tn: 26709.0000 - tp: 1933.0000 - precision: 0.1141 - recall: 0.5961 - val_loss: 2.9910e-05 - val_fn: 341.0000 - val_fp: 4025.0000 - val_tn: 6373.0000 - val_tp: 500.0000 - val_precision: 0.1105 - val_recall: 0.5945
# Epoch 80/100
# 44956/44956 - 2s - loss: 2.9193e-05 - fn: 1351.0000 - fp: 14792.0000 - tn: 26921.0000 - tp: 1892.0000 - precision: 0.1134 - recall: 0.5834 - val_loss: 2.9914e-05 - val_fn: 341.0000 - val_fp: 4008.0000 - val_tn: 6390.0000 - val_tp: 500.0000 - val_precision: 0.1109 - val_recall: 0.5945
# Epoch 81/100
# 44956/44956 - 2s - loss: 2.9185e-05 - fn: 1347.0000 - fp: 15040.0000 - tn: 26673.0000 - tp: 1896.0000 - precision: 0.1120 - recall: 0.5846 - val_loss: 2.9913e-05 - val_fn: 337.0000 - val_fp: 4084.0000 - val_tn: 6314.0000 - val_tp: 504.0000 - val_precision: 0.1099 - val_recall: 0.5993
# Epoch 82/100
# 44956/44956 - 2s - loss: 2.9042e-05 - fn: 1299.0000 - fp: 15099.0000 - tn: 26614.0000 - tp: 1944.0000 - precision: 0.1141 - recall: 0.5994 - val_loss: 2.9912e-05 - val_fn: 340.0000 - val_fp: 4039.0000 - val_tn: 6359.0000 - val_tp: 501.0000 - val_precision: 0.1104 - val_recall: 0.5957
# Epoch 83/100
# 44956/44956 - 2s - loss: 2.9121e-05 - fn: 1329.0000 - fp: 14490.0000 - tn: 27223.0000 - tp: 1914.0000 - precision: 0.1167 - recall: 0.5902 - val_loss: 2.9911e-05 - val_fn: 337.0000 - val_fp: 4071.0000 - val_tn: 6327.0000 - val_tp: 504.0000 - val_precision: 0.1102 - val_recall: 0.5993
# Epoch 84/100
# 44956/44956 - 2s - loss: 2.9104e-05 - fn: 1345.0000 - fp: 14867.0000 - tn: 26846.0000 - tp: 1898.0000 - precision: 0.1132 - recall: 0.5853 - val_loss: 2.9910e-05 - val_fn: 340.0000 - val_fp: 4033.0000 - val_tn: 6365.0000 - val_tp: 501.0000 - val_precision: 0.1105 - val_recall: 0.5957
# Epoch 85/100
# 44956/44956 - 2s - loss: 2.9047e-05 - fn: 1329.0000 - fp: 14985.0000 - tn: 26728.0000 - tp: 1914.0000 - precision: 0.1133 - recall: 0.5902 - val_loss: 2.9906e-05 - val_fn: 330.0000 - val_fp: 4108.0000 - val_tn: 6290.0000 - val_tp: 511.0000 - val_precision: 0.1106 - val_recall: 0.6076
# Epoch 86/100
# 44956/44956 - 2s - loss: 2.9139e-05 - fn: 1330.0000 - fp: 15081.0000 - tn: 26632.0000 - tp: 1913.0000 - precision: 0.1126 - recall: 0.5899 - val_loss: 2.9904e-05 - val_fn: 340.0000 - val_fp: 4024.0000 - val_tn: 6374.0000 - val_tp: 501.0000 - val_precision: 0.1107 - val_recall: 0.5957
# Epoch 87/100
# 44956/44956 - 2s - loss: 2.9078e-05 - fn: 1318.0000 - fp: 14993.0000 - tn: 26720.0000 - tp: 1925.0000 - precision: 0.1138 - recall: 0.5936 - val_loss: 2.9902e-05 - val_fn: 329.0000 - val_fp: 4121.0000 - val_tn: 6277.0000 - val_tp: 512.0000 - val_precision: 0.1105 - val_recall: 0.6088
# Epoch 88/100
# 44956/44956 - 2s - loss: 2.9126e-05 - fn: 1342.0000 - fp: 14875.0000 - tn: 26838.0000 - tp: 1901.0000 - precision: 0.1133 - recall: 0.5862 - val_loss: 2.9898e-05 - val_fn: 339.0000 - val_fp: 4017.0000 - val_tn: 6381.0000 - val_tp: 502.0000 - val_precision: 0.1111 - val_recall: 0.5969
# Epoch 89/100
# 44956/44956 - 2s - loss: 2.9034e-05 - fn: 1309.0000 - fp: 14999.0000 - tn: 26714.0000 - tp: 1934.0000 - precision: 0.1142 - recall: 0.5964 - val_loss: 2.9904e-05 - val_fn: 332.0000 - val_fp: 4090.0000 - val_tn: 6308.0000 - val_tp: 509.0000 - val_precision: 0.1107 - val_recall: 0.6052
# Epoch 90/100
# 44956/44956 - 2s - loss: 2.9081e-05 - fn: 1342.0000 - fp: 14871.0000 - tn: 26842.0000 - tp: 1901.0000 - precision: 0.1133 - recall: 0.5862 - val_loss: 2.9904e-05 - val_fn: 335.0000 - val_fp: 4057.0000 - val_tn: 6341.0000 - val_tp: 506.0000 - val_precision: 0.1109 - val_recall: 0.6017
# Epoch 91/100
# 44956/44956 - 2s - loss: 2.9121e-05 - fn: 1315.0000 - fp: 14976.0000 - tn: 26737.0000 - tp: 1928.0000 - precision: 0.1141 - recall: 0.5945 - val_loss: 2.9899e-05 - val_fn: 330.0000 - val_fp: 4118.0000 - val_tn: 6280.0000 - val_tp: 511.0000 - val_precision: 0.1104 - val_recall: 0.6076
# Epoch 92/100
# 44956/44956 - 2s - loss: 2.9006e-05 - fn: 1328.0000 - fp: 14812.0000 - tn: 26901.0000 - tp: 1915.0000 - precision: 0.1145 - recall: 0.5905 - val_loss: 2.9901e-05 - val_fn: 335.0000 - val_fp: 4035.0000 - val_tn: 6363.0000 - val_tp: 506.0000 - val_precision: 0.1114 - val_recall: 0.6017
# Epoch 93/100
# 44956/44956 - 2s - loss: 2.8927e-05 - fn: 1320.0000 - fp: 14725.0000 - tn: 26988.0000 - tp: 1923.0000 - precision: 0.1155 - recall: 0.5930 - val_loss: 2.9899e-05 - val_fn: 331.0000 - val_fp: 4075.0000 - val_tn: 6323.0000 - val_tp: 510.0000 - val_precision: 0.1112 - val_recall: 0.6064
# Epoch 94/100
# 44956/44956 - 2s - loss: 2.9019e-05 - fn: 1303.0000 - fp: 15010.0000 - tn: 26703.0000 - tp: 1940.0000 - precision: 0.1145 - recall: 0.5982 - val_loss: 2.9897e-05 - val_fn: 332.0000 - val_fp: 4078.0000 - val_tn: 6320.0000 - val_tp: 509.0000 - val_precision: 0.1110 - val_recall: 0.6052
# Epoch 95/100
# 44956/44956 - 2s - loss: 2.9057e-05 - fn: 1289.0000 - fp: 14865.0000 - tn: 26848.0000 - tp: 1954.0000 - precision: 0.1162 - recall: 0.6025 - val_loss: 2.9890e-05 - val_fn: 333.0000 - val_fp: 4054.0000 - val_tn: 6344.0000 - val_tp: 508.0000 - val_precision: 0.1114 - val_recall: 0.6040
# Epoch 96/100
# 44956/44956 - 2s - loss: 2.9049e-05 - fn: 1327.0000 - fp: 14843.0000 - tn: 26870.0000 - tp: 1916.0000 - precision: 0.1143 - recall: 0.5908 - val_loss: 2.9890e-05 - val_fn: 333.0000 - val_fp: 4075.0000 - val_tn: 6323.0000 - val_tp: 508.0000 - val_precision: 0.1108 - val_recall: 0.6040
# Epoch 97/100
# 44956/44956 - 2s - loss: 2.9028e-05 - fn: 1312.0000 - fp: 15044.0000 - tn: 26669.0000 - tp: 1931.0000 - precision: 0.1138 - recall: 0.5954 - val_loss: 2.9891e-05 - val_fn: 331.0000 - val_fp: 4110.0000 - val_tn: 6288.0000 - val_tp: 510.0000 - val_precision: 0.1104 - val_recall: 0.6064
# Epoch 98/100
# 44956/44956 - 2s - loss: 2.9003e-05 - fn: 1297.0000 - fp: 15133.0000 - tn: 26580.0000 - tp: 1946.0000 - precision: 0.1139 - recall: 0.6001 - val_loss: 2.9888e-05 - val_fn: 326.0000 - val_fp: 4167.0000 - val_tn: 6231.0000 - val_tp: 515.0000 - val_precision: 0.1100 - val_recall: 0.6124
# Epoch 99/100
# 44956/44956 - 2s - loss: 2.8962e-05 - fn: 1286.0000 - fp: 14911.0000 - tn: 26802.0000 - tp: 1957.0000 - precision: 0.1160 - recall: 0.6035 - val_loss: 2.9887e-05 - val_fn: 334.0000 - val_fp: 4088.0000 - val_tn: 6310.0000 - val_tp: 507.0000 - val_precision: 0.1103 - val_recall: 0.6029
# Epoch 100/100
# 44956/44956 - 2s - loss: 2.9028e-05 - fn: 1322.0000 - fp: 14855.0000 - tn: 26858.0000 - tp: 1921.0000 - precision: 0.1145 - recall: 0.5924 - val_loss: 2.9886e-05 - val_fn: 334.0000 - val_fp: 4118.0000 - val_tn: 6280.0000 - val_tp: 507.0000 - val_precision: 0.1096 - val_recall: 0.6029

# %%
# Predicting the Test set results
y_pred_val = model.predict(val_features)
y_pred_val[y_pred_val > 0.5] = 1
y_pred_val[y_pred_val <=0.5] = 0
y_pred_val.reshape((y_pred_val.shape[0]))
# predict the training set
y_pred_train = model.predict(train_features)
y_pred_train[y_pred_train > 0.5] = 1
y_pred_train[y_pred_train <=0.5] = 0
y_pred_train.reshape((y_pred_train.shape[0]))
# Out:
# array([0., 0., 0., ..., 0., 0., 0.], dtype=float32)

# %%
# Squeezing
val_targets = np.squeeze(val_targets)
y_pred_val = np.squeeze(y_pred_val)
train_targets = np.squeeze(train_targets)
y_pred_train = np.squeeze(y_pred_train)

# False Negative Testing
fn_val = FalseNegatives()
fn_val.update_state(val_targets, y_pred_val)
fn_val = fn_val.result().numpy()

# False Negative Training
fn_train = FalseNegatives()
fn_train.update_state(train_targets, y_pred_train)
fn_train = fn_train.result().numpy()

#False Positive Testing
fp_val = FalsePositives()
fp_val.update_state(val_targets, y_pred_val)
fp_val = fp_val.result().numpy()
#
#False Positive Training
fp_train = FalsePositives()
fp_train.update_state(train_targets, y_pred_train)
fp_train = fp_train.result().numpy()

# Precision validación
pre_val = Precision()
pre_val.update_state(val_targets, y_pred_val)
pre_val = pre_val.result().numpy()

# Precision training
pre_train = Precision()
pre_train.update_state(train_targets, y_pred_train)
pre_train = pre_train.result().numpy()
#
# recall validation
re_val = Recall()
re_val.update_state(val_targets, y_pred_val)
re_val = re_val.result().numpy()
#
# recall testing
re_train = Recall()
re_train.update_state(train_targets, y_pred_train)
re_train = re_train.result().numpy()
# 

#metrics
metrics = {'False_positive_training':fp_train, 'False_positive_testing':fp_val,
           '%False_positives': np.round((fp_train+fp_val)/ len(X_train)*100,1),
           'Falses_negatives_training':fn_train, 'False_negatives_testing':fn_val,
           '%False_negatives': np.round((fn_train+fn_val)/ len(X_train)*100,1),
           'Precision_train': np.round(pre_train,2), 'Precision_testing': np.round(pre_val,2),
           'Recall_train': np.round(re_train,2), 'Recall_testing':np.round(re_val,2) }
metrics
# Out:
# {'False_positive_training': 15188.0,
#  'False_positive_testing': 4118.0,
#  '%False_positives': 42.9,
#  'Falses_negatives_training': 1192.0,
#  'False_negatives_testing': 334.0,
#  '%False_negatives': 3.4,
#  'Precision_train': 0.12,
#  'Precision_testing': 0.11,
#  'Recall_train': 0.63,
#  'Recall_testing': 0.6}

# %%
def plot_metric(history, metric):
    train_metrics = history.history[metric]
    tes_metrics = history.history['val_'+metric]
    epochs = range(1, len(train_metrics) + 1)
    plt.plot(epochs, train_metrics, 'bo--')
    plt.plot(epochs, tes_metrics, 'ro-')
    plt.title('Training and Testing  '+ metric)
    plt.xlabel("Epochs")
    plt.ylabel(metric)
    plt.legend(["train_"+metric, 'tes_'+metric])
    plt.show()
plot_metric(history, 'loss')

# %% [markdown]
# ## IV. Oversampling

# %% [markdown]
# Unbalanced data substantially compromises the learning process, since most of the standard machine learning algorithms expect balanced class distribution or an equal misclassification cost  (He and Garcia, 2009). I worked with the package imbalanced-learn which offers a number of re-sampling techniques, in order to apply the SMOTE methodology where the data balancing can be performed by oversampling such that new samples are generated the smallest class to reach the balancing ratio (Lemaitre, Nogueira and Aridas, 2017)

# %%
X=dataset.drop([ 'Unnamed: 0','encounter_id', 'patient_nbr','readmitted', 'gender_Female'] , axis=1)
y=dataset['readmitted']

# %%
sm=SMOTE(random_state=42)
X_res, y_res=sm.fit_sample(X,y)
print('Original dataset shape %s' % Counter(y))
print('Resampled dataset shape %s' % Counter(y_res))
# Out:
# Original dataset shape Counter({0: 52111, 1: 4084})
# Resampled dataset shape Counter({1: 52111, 0: 52111})

# %%
X_train, X_test, y_train, y_test = train_test_split(X_res, 
                                                    y_res,
                                                    test_size=0.2,
                                                    stratify=y_res,
                                                    random_state=42)
print('Training samples: {}'.format(X_train.shape[0]))
print('Testing samples: {}'.format(X_test.shape[0]))
print('Number of features: {}'.format(X_train.shape[1]))
print('Training outcome distribution: {}'.format(np.bincount(y_train)))
print('Testing outcome distribution: {}'.format(np.bincount(y_test)))
# Out:
# Training samples: 83377
# Testing samples: 20845
# Number of features: 52
# Training outcome distribution: [41688 41689]
# Testing outcome distribution: [10423 10422]

# %% [markdown]
# #### 1. Logistic Regression

# %%
classifier = LogisticRegression(max_iter=10000,random_state=0)
classifier.fit(X_train, y_train)
over_logistic_prediction = classifier.predict(X_test)
model_performance(over_logistic_prediction)
# Out:
#               precision    recall  f1-score   support
#
#            0      0.912     0.999     0.954     10423
#            1      0.999     0.904     0.949     10422
#
#     accuracy                          0.952     20845
#    macro avg      0.956     0.952     0.951     20845
# weighted avg      0.956     0.952     0.951     20845
#
# Confusion Matrix:
#  [[10417     6]
#  [ 1003  9419]]
#
# True Negative: 10417
# False Positive: 6
# False Negative: 1003
# True Positive: 9419
# Correct Predictions 95.2 %

# %%
coeff = list(classifier.coef_[0])
labels = list(X_train.columns)
features = pd.DataFrame()
features['Features'] = labels
features['coef'] = coeff
features.sort_values(by=['coef'], ascending=True, inplace=True)
features['positive'] = features['coef'] > 0
features.set_index('Features', inplace=True)
features.coef.plot(kind='barh', figsize=(11, 10),color = features.positive.map({True: 'blue', False: 'red'}))
plt.xlabel('Coefficient Value')
# Out:
# Text(0.5, 0, 'Coefficient Value')

# %%
p_values= list(f_regression(X_train, y_train,center=True)[1])
features['p-values'] = p_values
features['odds'] = np.exp(features['coef'])
features=features.drop(['positive'], axis=1)
features
# Out:
#                                coef       p-values      odds
# Features
# age_Less_fourty           -6.027045   2.575872e-21  0.002413
# age_Between_fourty_sixty  -6.018576   3.615300e-62  0.002433
# diag_type_Respiratory     -5.813780  1.540686e-221  0.002986
# insulin_No                -5.802485   9.974274e-53  0.003020
# age_Between_sixty_seventy -5.757672   8.076548e-52  0.003158
# diag_type_Genitourinary   -5.678561   3.030946e-22  0.003418
# diag_type_Digestive       -5.625672  3.862252e-145  0.003604
# diag_type_Neoplasms       -5.601208   6.805381e-70  0.003693
# insulin_Steady            -5.593660   0.000000e+00  0.003721
# age_Greater_seventy       -5.581581  3.587714e-124  0.003767
# diag_type_Musculoskeletal -5.528191   0.000000e+00  0.003973
# diag_type_Injury          -5.515315   8.551744e-01  0.004025
# insulin_Up                -5.495137  1.219428e-242  0.004107
# diag_type_Other           -5.473955   0.000000e+00  0.004195
# insulin_Down              -5.329469   1.781179e-53  0.004847
# diag_type_Circulatory     -5.268168  9.570939e-115  0.005153
# diag_type_Diabetes        -5.011710  8.992780e-142  0.006660
# race_Other                -4.902041  7.728137e-128  0.007431
# race_AfricanAmerican      -4.856885   0.000000e+00  0.007775
# race_Hispanic             -4.695089  9.112684e-258  0.009140
# glipizide_No              -4.635013   0.000000e+00  0.009706
# race_Caucasian            -4.519912   0.000000e+00  0.010890
# glipizide_Steady          -4.518974   0.000000e+00  0.010900
# A1Cresult_8               -4.508096   0.000000e+00  0.011019
# A1Cresult_7               -4.481756   0.000000e+00  0.011314
# A1Cresult_Norm            -4.472341  2.399758e-148  0.011421
# glipizide_Up              -4.468548   0.000000e+00  0.011464
# race_Asian                -4.417591  1.699267e-275  0.012063
# metformin_Up              -4.378984   0.000000e+00  0.012538
# metformin_Steady          -4.358790   1.087357e-81  0.012794
# metformin_No              -4.250392   0.000000e+00  0.014259
# A1Cresult_None            -4.114982   0.000000e+00  0.016326
# glyburide_Steady          -4.066521   1.846159e-22  0.017137
# glipizide_Down            -4.019690   0.000000e+00  0.017959
# glyburide_No              -4.011850  2.482708e-288  0.018100
# glyburide_Down            -3.951673  3.756591e-271  0.019223
# metformin_Down            -3.921810  1.797752e-232  0.019805
# glyburide_Up              -3.793497  2.623479e-239  0.022517
# admission_type            -0.566517   0.000000e+00  0.567499
# Admision_source           -0.534539   0.000000e+00  0.585939
# change                    -0.224116   3.024913e-42  0.799222
# diabetesMed               -0.096266  6.391153e-119  0.908222
# gender_Male               -0.076005   0.000000e+00  0.926811
# num_procedures            -0.067162   1.311233e-88  0.935044
# number_outpatient         -0.043511   2.639579e-26  0.957422
# time_in_hospital          -0.005395  4.246395e-319  0.994620
# num_lab_procedures         0.002867   0.000000e+00  1.002871
# num_medications            0.003078   1.081908e-51  1.003083
# number_emergency           0.025707   1.334746e-37  1.026040
# number_diagnoses           0.053530  2.021509e-129  1.054989
# Discharged_type            0.295647   0.000000e+00  1.343995
# number_inpatient           0.313646   4.059957e-52  1.368405

# %% [markdown]
# ### 2. KNeighbors

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors=200)
classifier.fit(X_train, y_train)
k_prediction = classifier.predict(X_test)
model_performance(k_prediction)
# Out:
#               precision    recall  f1-score   support
#
#            0      0.799     0.369     0.505     10423
#            1      0.590     0.907     0.715     10422
#
#     accuracy                          0.638     20845
#    macro avg      0.695     0.638     0.610     20845
# weighted avg      0.695     0.638     0.610     20845
#
# Confusion Matrix:
#  [[3849 6574]
#  [ 966 9456]]
#
# True Negative: 3849
# False Positive: 6574
# False Negative: 966
# True Positive: 9456
# Correct Predictions 63.8 %

# %% [markdown]
# ### 3. Random Forest

# %%
clf=RandomForestClassifier(n_estimators=1000)
clf.fit(X_train,y_train)
random_f_prediction=clf.predict(X_test)
model_performance(random_f_prediction)
# Out:
#               precision    recall  f1-score   support
#
#            0      0.927     0.998     0.961     10423
#            1      0.998     0.922     0.958     10422
#
#     accuracy                          0.960     20845
#    macro avg      0.963     0.960     0.960     20845
# weighted avg      0.963     0.960     0.960     20845
#
# Confusion Matrix:
#  [[10402    21]
#  [  814  9608]]
#
# True Negative: 10402
# False Positive: 21
# False Negative: 814
# True Positive: 9608
# Correct Predictions 96.0 %

# %%
feature_imp = pd.Series(clf.feature_importances_,index=X_train.columns).sort_values(ascending=False)
feature_imp
# Out:
# num_lab_procedures           0.056444
# age_Between_fourty_sixty     0.054362
# num_medications              0.048849
# insulin_No                   0.045055
# age_Greater_seventy          0.044987
# insulin_Steady               0.041849
# age_Between_sixty_seventy    0.040685
# time_in_hospital             0.034359
# diag_type_Respiratory        0.030104
# metformin_No                 0.029542
# age_Less_fourty              0.028841
# diag_type_Other              0.028023
# admission_type               0.026465
# diag_type_Circulatory        0.026405
# race_AfricanAmerican         0.026251
# Admision_source              0.025778
# number_diagnoses             0.025223
# num_procedures               0.025005
# gender_Male                  0.022992
# diag_type_Digestive          0.022563
# change                       0.022299
# metformin_Steady             0.022152
# race_Caucasian               0.021869
# insulin_Up                   0.020551
# insulin_Down                 0.019503
# glipizide_No                 0.017372
# number_inpatient             0.017344
# diag_type_Injury             0.016104
# diabetesMed                  0.015750
# diag_type_Genitourinary      0.014505
# glipizide_Steady             0.012517
# glyburide_No                 0.011937
# Discharged_type              0.010848
# diag_type_Musculoskeletal    0.009647
# A1Cresult_None               0.009548
# A1Cresult_8                  0.009473
# number_outpatient            0.009450
# diag_type_Neoplasms          0.008651
# glyburide_Steady             0.008486
# A1Cresult_Norm               0.006861
# number_emergency             0.006247
# A1Cresult_7                  0.005276
# race_Hispanic                0.004861
# race_Other                   0.004095
# metformin_Up                 0.003214
# race_Asian                   0.001682
# metformin_Down               0.001635
# glipizide_Up                 0.001303
# glyburide_Up                 0.001001
# glipizide_Down               0.000903
# glyburide_Down               0.000749
# diag_type_Diabetes           0.000385
# dtype: float64

# %% [markdown]
# ### 4. Decision Tree Classifier

# %%
tree = DecisionTreeClassifier(max_depth=20, random_state=42) # vamos a usar un árbol de profundidad 2
tree.fit(X_train, y_train)
pred_tree=tree.predict(X_test) 
model_performance(pred_tree)
# Out:
#               precision    recall  f1-score   support
#
#            0      0.924     0.917     0.921     10423
#            1      0.918     0.925     0.921     10422
#
#     accuracy                          0.921     20845
#    macro avg      0.921     0.921     0.921     20845
# weighted avg      0.921     0.921     0.921     20845
#
# Confusion Matrix:
#  [[9559  864]
#  [ 786 9636]]
#
# True Negative: 9559
# False Positive: 864
# False Negative: 786
# True Positive: 9636
# Correct Predictions 92.1 %

# %%
viz = FeatureImportances(tree)
viz.fit(X_res, y_res)
viz.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:213: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
# <AxesSubplot:title={'center':'Feature Importances of 52 Features using DecisionTreeClassifier'}, xlabel='relative importance'>
